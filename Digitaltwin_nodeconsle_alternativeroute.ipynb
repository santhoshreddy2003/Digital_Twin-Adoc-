# %%
import tkinter as tk
import threading
import time
from queue import Queue
import requests
import folium
import openrouteservice as ors
from IPython.display import display  # For map display in Jupyter-like environments


class NodeHubSystem:
    def __init__(self):
        self.node_queues = [Queue() for _ in range(3)]  # Queues for Node 1, Node 2, Node 3
        self.hub_queue = Queue()  # Queue for the Hub
        self.sent_alerts = set()
        self.node_windows = []
        self.alert_generated = False  # Track if an alert has been generated

        # Source and destination locations (geocoded coordinates for Beeramguda and Kukatpally)
        self.source = [78.3033, 17.5019]  # Beeramguda (approximate coordinates)
        self.destination = [78.4138, 17.4949]  # Kukatpally (approximate coordinates)

        # Initialize OpenRouteService client
        self.client = ors.Client(key='5b3ce3597851110001cf6248f71e4da02d6f409bb1bc92a59f0d107e')

    def start(self):
        # Create windows for nodes and hub
        for i in range(3):
            threading.Thread(target=self.create_node_window, args=(i,), daemon=True).start()

        threading.Thread(target=self.create_hub_window, daemon=True).start()

        # Start monitoring ThingSpeak channels
        threading.Thread(target=self.monitor_sensors, daemon=True).start()

        # Start the Tkinter GUI to show the map
        threading.Thread(target=self.create_map_window, daemon=True).start()

    def create_node_window(self, node_id):
        def process_queue():
            while not self.node_queues[node_id].empty():
                message = self.node_queues[node_id].get()
                text_widget.insert(tk.END, message + "\n")
                text_widget.see(tk.END)
            root.after(100, process_queue)

        root = tk.Tk()
        root.title(f"Node {node_id + 1} Console")
        text_widget = tk.Text(root, height=20, width=50)
        text_widget.pack()

        process_queue()
        root.mainloop()

    def create_hub_window(self):
        def process_queue():
            while not self.hub_queue.empty():
                message = self.hub_queue.get()
                text_widget.insert(tk.END, message + "\n")
                text_widget.see(tk.END)
            root.after(100, process_queue)

        root = tk.Tk()
        root.title("Hub Console")
        text_widget = tk.Text(root, height=20, width=50)
        text_widget.pack()

        process_queue()
        root.mainloop()

    def create_map_window(self):
        def update_map():
            self.generate_map()
            root.after(5000, update_map)  # Refresh map every 5 seconds

        root = tk.Tk()
        root.title("Map Display")
        root.geometry("800x600")

        map_frame = tk.Frame(root)
        map_frame.pack(fill=tk.BOTH, expand=True)

        update_map()
        root.mainloop()

    def monitor_sensors(self):
        # ThingSpeak Channel Details
        channels = [
            {"id": "2784770", "api_key": "I6I38IODBRXVZCAV"},
            {"id": "2795362", "api_key": "225NJ2MKZB1U4RH0"},
            {"id": "2795423", "api_key": "ZZJLS0LI3ZUS7W84"},
        ]

        while True:
            sensor_data = [
                self.fetch_last_values(channel["id"], channel["api_key"], 8)
                for channel in channels
            ]

            alert_conditions = [self.check_alert_conditions(data) for data in sensor_data]

            self.handle_alerts(alert_conditions)
            time.sleep(5)

    def fetch_last_values(self, channel_id, api_key, field_count):
        url = f"https://api.thingspeak.com/channels/{channel_id}/feeds.json"
        params = {"api_key": api_key, "results": 1}
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()
            if data and "feeds" in data and len(data["feeds"]) > 0:
                last_entry = data["feeds"][-1]
                sensor_data = {}
                for field_num in range(1, field_count + 1):
                    sensor_data[f"field{field_num}"] = last_entry.get(f"field{field_num}")
                return sensor_data
            else:
                return None
        else:
            return None

    def check_alert_conditions(self, sensor_data):
        if sensor_data:
            field_6 = float(sensor_data.get("field6", 0))
            field_7 = float(sensor_data.get("field7", 0))
            field_8 = float(sensor_data.get("field8", 0))

            return field_6 < 5 and field_7 == 0 and field_8 == 0
        return False

    def handle_alerts(self, alert_conditions):
        nodes_with_alerts = [i for i, condition in enumerate(alert_conditions) if condition]

        if len(nodes_with_alerts) > 0:
            alert_key = tuple(sorted(nodes_with_alerts))

            if alert_key not in self.sent_alerts:
                message = f"Accident occurred at Nodes: {', '.join(f'Node {n + 1}' for n in nodes_with_alerts)}!"
                self.hub_queue.put(message)
                self.sent_alerts.add(alert_key)

                for i, queue in enumerate(self.node_queues):
                    if i not in nodes_with_alerts:
                        queue.put(message)

                # Set the alert flag and display the second alternative route
                self.alert_generated = True
        else:
            self.alert_generated = False  # No alert, show default route

    def generate_map(self):
        # Create a map centered at the source location
        m = folium.Map(location=list(reversed(self.source)), tiles="cartodbpositron", zoom_start=14)

        # Add markers for source and destination
        folium.Marker(location=list(reversed(self.source)), icon=folium.Icon(color="red", icon="cloud"), popup="Beeramguda").add_to(m)
        folium.Marker(location=list(reversed(self.destination)), icon=folium.Icon(color="blue", icon="flag"), popup="Kukatpally").add_to(m)

        # Request two alternative routes from OpenRouteService
        routes = self.client.directions(
            coordinates=[self.source, self.destination],
            profile='driving-car',
            alternative_routes={"share_factor": 0.5, "target_count": 2},  # Request two alternative routes
            geometry=True
        )

        # Extract and represent the main route in red (if no alert)
        main_route_coords = ors.convert.decode_polyline(routes['routes'][0]['geometry'])
        folium.PolyLine(locations=[list(reversed(coord)) for coord in main_route_coords['coordinates']], color='red', weight=5, popup="Main Route").add_to(m)

        # If alert is generated, show the second optimized route in blue
        if self.alert_generated and len(routes['routes']) > 1:
            alternative_route_coords = ors.convert.decode_polyline(routes['routes'][1]['geometry'])
            folium.PolyLine(locations=[list(reversed(coord)) for coord in alternative_route_coords['coordinates']], color='blue', weight=5, popup="Alternative Route").add_to(m)

        display(m)  # This will display the map in Jupyter or a similar environment


# Run the Node-Hub system
if __name__ == "__main__":
    system = NodeHubSystem()
    system.start()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09cc0f2519b3236bc60187d8ab08894c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09cc0f2519b3236bc60187d8ab08894c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09cc0f2519b3236bc60187d8ab08894c = L.map(
#                 &quot;map_09cc0f2519b3236bc60187d8ab08894c&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8afcd3659f9223053aa5271bcb4ae650 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8afcd3659f9223053aa5271bcb4ae650.addTo(map_09cc0f2519b3236bc60187d8ab08894c);
#
#
#             var marker_9a65fc21628d5e79415b31fc7b9bfc0c = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_09cc0f2519b3236bc60187d8ab08894c);
#
#
#             var icon_05f8c207f14f0e6608bba75e9683fd05 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9a65fc21628d5e79415b31fc7b9bfc0c.setIcon(icon_05f8c207f14f0e6608bba75e9683fd05);
#
#
#         var popup_e5c9c877c6900570604db8c88a3c071a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edd8e1a581c51f2f33e8a4b8042f1fe9 = $(`&lt;div id=&quot;html_edd8e1a581c51f2f33e8a4b8042f1fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_e5c9c877c6900570604db8c88a3c071a.setContent(html_edd8e1a581c51f2f33e8a4b8042f1fe9);
#
#
#
#         marker_9a65fc21628d5e79415b31fc7b9bfc0c.bindPopup(popup_e5c9c877c6900570604db8c88a3c071a)
#         ;
#
#
#
#
#             var marker_a92d48b96e1af2a76f85a756e26acc8f = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_09cc0f2519b3236bc60187d8ab08894c);
#
#
#             var icon_431a3645ffe4ab8e5c609e6870de819f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a92d48b96e1af2a76f85a756e26acc8f.setIcon(icon_431a3645ffe4ab8e5c609e6870de819f);
#
#
#         var popup_118ce781bd449eb6d2dc3e6a537759d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b0837d6c04b31fa8dcf1d12f90bdc2c = $(`&lt;div id=&quot;html_4b0837d6c04b31fa8dcf1d12f90bdc2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_118ce781bd449eb6d2dc3e6a537759d5.setContent(html_4b0837d6c04b31fa8dcf1d12f90bdc2c);
#
#
#
#         marker_a92d48b96e1af2a76f85a756e26acc8f.bindPopup(popup_118ce781bd449eb6d2dc3e6a537759d5)
#         ;
#
#
#
#
#             var poly_line_c4a5ab79b6c7096623cbaef00ff0b4b6 = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_782e14d20593abed3c94f33083e55750 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_782e14d20593abed3c94f33083e55750&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_782e14d20593abed3c94f33083e55750 = L.map(
#                 &quot;map_782e14d20593abed3c94f33083e55750&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51d7378407b2c176e1d8a972549c8aec = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51d7378407b2c176e1d8a972549c8aec.addTo(map_782e14d20593abed3c94f33083e55750);
#
#
#             var marker_c197fbf68c95a00a5666e0a244ef0542 = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_782e14d20593abed3c94f33083e55750);
#
#
#             var icon_cce16dbbb0cde4f1efecbf7e02f9e6ca = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c197fbf68c95a00a5666e0a244ef0542.setIcon(icon_cce16dbbb0cde4f1efecbf7e02f9e6ca);
#
#
#         var popup_8285bd3f67599cd66ce4a7ad4729004f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92b7f084717975380400c6cfcde2c56d = $(`&lt;div id=&quot;html_92b7f084717975380400c6cfcde2c56d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_8285bd3f67599cd66ce4a7ad4729004f.setContent(html_92b7f084717975380400c6cfcde2c56d);
#
#
#
#         marker_c197fbf68c95a00a5666e0a244ef0542.bindPopup(popup_8285bd3f67599cd66ce4a7ad4729004f)
#         ;
#
#
#
#
#             var marker_6a4660ccafb6b8855c6e1ffd3a0363c9 = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_782e14d20593abed3c94f33083e55750);
#
#
#             var icon_837e7dd01f4654c017b6746714229f75 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6a4660ccafb6b8855c6e1ffd3a0363c9.setIcon(icon_837e7dd01f4654c017b6746714229f75);
#
#
#         var popup_be2f2132708db5d28c1f7a41796ad2aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51f9b59a0c30fcdb9e3992a9c419fcc4 = $(`&lt;div id=&quot;html_51f9b59a0c30fcdb9e3992a9c419fcc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_be2f2132708db5d28c1f7a41796ad2aa.setContent(html_51f9b59a0c30fcdb9e3992a9c419fcc4);
#
#
#
#         marker_6a4660ccafb6b8855c6e1ffd3a0363c9.bindPopup(popup_be2f2132708db5d28c1f7a41796ad2aa)
#         ;
#
#
#
#
#             var poly_line_b4bd29a2b76b9ea7e38786f137e9f831 = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e24483ca99505bb4a34cc84d4df489c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e24483ca99505bb4a34cc84d4df489c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e24483ca99505bb4a34cc84d4df489c = L.map(
#                 &quot;map_3e24483ca99505bb4a34cc84d4df489c&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0324de27a4c43a2e79defcb1d9116e5d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0324de27a4c43a2e79defcb1d9116e5d.addTo(map_3e24483ca99505bb4a34cc84d4df489c);
#
#
#             var marker_9b2d02e91f3550ca4945a9ede15a154b = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_3e24483ca99505bb4a34cc84d4df489c);
#
#
#             var icon_f6d0154e42dbfcdd8fe2d88b5eb14533 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9b2d02e91f3550ca4945a9ede15a154b.setIcon(icon_f6d0154e42dbfcdd8fe2d88b5eb14533);
#
#
#         var popup_1524a66273d676216dfa1f2d4b8d4708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a675e8cb13aef537c2b8600707b975d = $(`&lt;div id=&quot;html_5a675e8cb13aef537c2b8600707b975d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_1524a66273d676216dfa1f2d4b8d4708.setContent(html_5a675e8cb13aef537c2b8600707b975d);
#
#
#
#         marker_9b2d02e91f3550ca4945a9ede15a154b.bindPopup(popup_1524a66273d676216dfa1f2d4b8d4708)
#         ;
#
#
#
#
#             var marker_c3a731c565657e202d99d05931419993 = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_3e24483ca99505bb4a34cc84d4df489c);
#
#
#             var icon_1fd1b6b5e90e2ee8b269ddc1efc661c8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c3a731c565657e202d99d05931419993.setIcon(icon_1fd1b6b5e90e2ee8b269ddc1efc661c8);
#
#
#         var popup_d7bac58a93744ccb146f5243f2771c7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac040c756df89583ae032ed11aabdc52 = $(`&lt;div id=&quot;html_ac040c756df89583ae032ed11aabdc52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_d7bac58a93744ccb146f5243f2771c7a.setContent(html_ac040c756df89583ae032ed11aabdc52);
#
#
#
#         marker_c3a731c565657e202d99d05931419993.bindPopup(popup_d7bac58a93744ccb146f5243f2771c7a)
#         ;
#
#
#
#
#             var poly_line_1f9000649838dda55b4ac08a63cb9160 = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0836395138c02bdde038b3d263be94de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0836395138c02bdde038b3d263be94de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0836395138c02bdde038b3d263be94de = L.map(
#                 &quot;map_0836395138c02bdde038b3d263be94de&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0116cfbca288b5c2a2bf9d29895e5e9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0116cfbca288b5c2a2bf9d29895e5e9.addTo(map_0836395138c02bdde038b3d263be94de);
#
#
#             var marker_898a4458610663dd1c7aa937663fcc1d = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_0836395138c02bdde038b3d263be94de);
#
#
#             var icon_6ef5fb60dcbac7ac27fb9d190bebfb6e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_898a4458610663dd1c7aa937663fcc1d.setIcon(icon_6ef5fb60dcbac7ac27fb9d190bebfb6e);
#
#
#         var popup_ebdb795c0c97027bc333c81ae285e653 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_455a752a96adbb7c4914cab99d69a019 = $(`&lt;div id=&quot;html_455a752a96adbb7c4914cab99d69a019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_ebdb795c0c97027bc333c81ae285e653.setContent(html_455a752a96adbb7c4914cab99d69a019);
#
#
#
#         marker_898a4458610663dd1c7aa937663fcc1d.bindPopup(popup_ebdb795c0c97027bc333c81ae285e653)
#         ;
#
#
#
#
#             var marker_9eb0b91cbfbef73db1d313c48496ee78 = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_0836395138c02bdde038b3d263be94de);
#
#
#             var icon_52da625d60485d922aa733d2594fb889 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_9eb0b91cbfbef73db1d313c48496ee78.setIcon(icon_52da625d60485d922aa733d2594fb889);
#
#
#         var popup_185d506b2ae45434f57c79adc8b4b7e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19da8e8fb75a5e840a84631aa54ce6e8 = $(`&lt;div id=&quot;html_19da8e8fb75a5e840a84631aa54ce6e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_185d506b2ae45434f57c79adc8b4b7e2.setContent(html_19da8e8fb75a5e840a84631aa54ce6e8);
#
#
#
#         marker_9eb0b91cbfbef73db1d313c48496ee78.bindPopup(popup_185d506b2ae45434f57c79adc8b4b7e2)
#         ;
#
#
#
#
#             var poly_line_216305acbcfb944c928f5062fd18d0f7 = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_806a5f3df61b9fafcdc30cf96dd9a1cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_806a5f3df61b9fafcdc30cf96dd9a1cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_806a5f3df61b9fafcdc30cf96dd9a1cc = L.map(
#                 &quot;map_806a5f3df61b9fafcdc30cf96dd9a1cc&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d57a0505f0f2be49b4d4636c8275cbf1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d57a0505f0f2be49b4d4636c8275cbf1.addTo(map_806a5f3df61b9fafcdc30cf96dd9a1cc);
#
#
#             var marker_53a92fd9473bcce1f94fe6757468e694 = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_806a5f3df61b9fafcdc30cf96dd9a1cc);
#
#
#             var icon_1e8f98062384d13a797dda302d3a9ae1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_53a92fd9473bcce1f94fe6757468e694.setIcon(icon_1e8f98062384d13a797dda302d3a9ae1);
#
#
#         var popup_66137fb4f7d3f51c334d21215c5ea0f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a80d9efd69fca27e93b555447cb30db = $(`&lt;div id=&quot;html_4a80d9efd69fca27e93b555447cb30db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_66137fb4f7d3f51c334d21215c5ea0f1.setContent(html_4a80d9efd69fca27e93b555447cb30db);
#
#
#
#         marker_53a92fd9473bcce1f94fe6757468e694.bindPopup(popup_66137fb4f7d3f51c334d21215c5ea0f1)
#         ;
#
#
#
#
#             var marker_3b359e663dc9c9455265d7d51d61120c = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_806a5f3df61b9fafcdc30cf96dd9a1cc);
#
#
#             var icon_d5a39db37162d1f69c83d183b7b686df = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3b359e663dc9c9455265d7d51d61120c.setIcon(icon_d5a39db37162d1f69c83d183b7b686df);
#
#
#         var popup_1125d7e86e90cf298af6dfde50f45fae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6749f2f6022799cc2f15c85366610f00 = $(`&lt;div id=&quot;html_6749f2f6022799cc2f15c85366610f00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_1125d7e86e90cf298af6dfde50f45fae.setContent(html_6749f2f6022799cc2f15c85366610f00);
#
#
#
#         marker_3b359e663dc9c9455265d7d51d61120c.bindPopup(popup_1125d7e86e90cf298af6dfde50f45fae)
#         ;
#
#
#
#
#             var poly_line_814f08db44439abaac0a1ab604043725 = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dabf22e00a119d39ca6556db79369146 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dabf22e00a119d39ca6556db79369146&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dabf22e00a119d39ca6556db79369146 = L.map(
#                 &quot;map_dabf22e00a119d39ca6556db79369146&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_720b385a49f8d76a9c6b76b7b06fb0c4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_720b385a49f8d76a9c6b76b7b06fb0c4.addTo(map_dabf22e00a119d39ca6556db79369146);
#
#
#             var marker_6029bd09082b24be7302322cce6b08ed = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_dabf22e00a119d39ca6556db79369146);
#
#
#             var icon_e2393968d9202cef68ad39ee5e22c183 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6029bd09082b24be7302322cce6b08ed.setIcon(icon_e2393968d9202cef68ad39ee5e22c183);
#
#
#         var popup_62a00eda48b296b3945a2698c3b7308f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b6899dc06577147be5b2fee9f4da17e = $(`&lt;div id=&quot;html_0b6899dc06577147be5b2fee9f4da17e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_62a00eda48b296b3945a2698c3b7308f.setContent(html_0b6899dc06577147be5b2fee9f4da17e);
#
#
#
#         marker_6029bd09082b24be7302322cce6b08ed.bindPopup(popup_62a00eda48b296b3945a2698c3b7308f)
#         ;
#
#
#
#
#             var marker_237be0d1a6d1b4166017c8f1eff76e42 = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_dabf22e00a119d39ca6556db79369146);
#
#
#             var icon_b1c74542198d700e98e06a9124e65219 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_237be0d1a6d1b4166017c8f1eff76e42.setIcon(icon_b1c74542198d700e98e06a9124e65219);
#
#
#         var popup_294358b5dc6a0e708accb03399b83950 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_659834bf8b74cde98e7732ca6d027125 = $(`&lt;div id=&quot;html_659834bf8b74cde98e7732ca6d027125&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_294358b5dc6a0e708accb03399b83950.setContent(html_659834bf8b74cde98e7732ca6d027125);
#
#
#
#         marker_237be0d1a6d1b4166017c8f1eff76e42.bindPopup(popup_294358b5dc6a0e708accb03399b83950)
#         ;
#
#
#
#
#             var poly_line_1c01903bd76b6a1436f114f3372a0aea = L.polyline(
# ...
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_828173b9e7b1cf740a2ea5c8be2e1387 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_828173b9e7b1cf740a2ea5c8be2e1387&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_828173b9e7b1cf740a2ea5c8be2e1387 = L.map(
#                 &quot;map_828173b9e7b1cf740a2ea5c8be2e1387&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57e0618172e3439900510ce7754b6595 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57e0618172e3439900510ce7754b6595.addTo(map_828173b9e7b1cf740a2ea5c8be2e1387);
#
#
#             var marker_e2126a7db713c8f3f2a64dd80f02d8b7 = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_828173b9e7b1cf740a2ea5c8be2e1387);
#
#
#             var icon_8660cb77ce9f514c89b9c5771cf8e3da = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e2126a7db713c8f3f2a64dd80f02d8b7.setIcon(icon_8660cb77ce9f514c89b9c5771cf8e3da);
#
#
#         var popup_d0b9d2edd0f4ad4792c15d75ab5f3393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d490181cae5daf3318da3afed6177b73 = $(`&lt;div id=&quot;html_d490181cae5daf3318da3afed6177b73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_d0b9d2edd0f4ad4792c15d75ab5f3393.setContent(html_d490181cae5daf3318da3afed6177b73);
#
#
#
#         marker_e2126a7db713c8f3f2a64dd80f02d8b7.bindPopup(popup_d0b9d2edd0f4ad4792c15d75ab5f3393)
#         ;
#
#
#
#
#             var marker_fb3c49d7b9299969d4c3534fec8ca3d8 = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_828173b9e7b1cf740a2ea5c8be2e1387);
#
#
#             var icon_83e93a451f497731b92169c6a2db9f21 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fb3c49d7b9299969d4c3534fec8ca3d8.setIcon(icon_83e93a451f497731b92169c6a2db9f21);
#
#
#         var popup_009fea3834ad1ab2b24a0c2489e2a986 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58f6a184bc0cad2b2c336c2dc1a196a3 = $(`&lt;div id=&quot;html_58f6a184bc0cad2b2c336c2dc1a196a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_009fea3834ad1ab2b24a0c2489e2a986.setContent(html_58f6a184bc0cad2b2c336c2dc1a196a3);
#
#
#
#         marker_fb3c49d7b9299969d4c3534fec8ca3d8.bindPopup(popup_009fea3834ad1ab2b24a0c2489e2a986)
#         ;
#
#
#
#
#             var poly_line_6b2a0d60219374444febaff881ef3233 = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25b373c9b62565603e5e5cae163b6f69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25b373c9b62565603e5e5cae163b6f69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25b373c9b62565603e5e5cae163b6f69 = L.map(
#                 &quot;map_25b373c9b62565603e5e5cae163b6f69&quot;,
#                 {
#                     center: [17.5019, 78.3033],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f0fba73d60157397c43244ac9a3c0c7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f0fba73d60157397c43244ac9a3c0c7.addTo(map_25b373c9b62565603e5e5cae163b6f69);
#
#
#             var marker_feee09c6887ab400e1dcc7695d9abf7c = L.marker(
#                 [17.5019, 78.3033],
#                 {
# }
#             ).addTo(map_25b373c9b62565603e5e5cae163b6f69);
#
#
#             var icon_942b287cada53d18256b8d6c17293d0b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_feee09c6887ab400e1dcc7695d9abf7c.setIcon(icon_942b287cada53d18256b8d6c17293d0b);
#
#
#         var popup_be8732a05ca8e4ef199911a186cc7e93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ccd8e0c61f0672190fa8fc345f1178c = $(`&lt;div id=&quot;html_3ccd8e0c61f0672190fa8fc345f1178c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beeramguda&lt;/div&gt;`)[0];
#                 popup_be8732a05ca8e4ef199911a186cc7e93.setContent(html_3ccd8e0c61f0672190fa8fc345f1178c);
#
#
#
#         marker_feee09c6887ab400e1dcc7695d9abf7c.bindPopup(popup_be8732a05ca8e4ef199911a186cc7e93)
#         ;
#
#
#
#
#             var marker_e56e5db5976aeb04393a4923730bfbe5 = L.marker(
#                 [17.4949, 78.4138],
#                 {
# }
#             ).addTo(map_25b373c9b62565603e5e5cae163b6f69);
#
#
#             var icon_2b8cfdd773d11485ae2bd441d8f9ef9c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;flag&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_e56e5db5976aeb04393a4923730bfbe5.setIcon(icon_2b8cfdd773d11485ae2bd441d8f9ef9c);
#
#
#         var popup_520e83a03b4c4f9237a851bf6c3decec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34d02457a37964e1aff6a1c21f7c7205 = $(`&lt;div id=&quot;html_34d02457a37964e1aff6a1c21f7c7205&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kukatpally&lt;/div&gt;`)[0];
#                 popup_520e83a03b4c4f9237a851bf6c3decec.setContent(html_34d02457a37964e1aff6a1c21f7c7205);
#
#
#
#         marker_e56e5db5976aeb04393a4923730bfbe5.bindPopup(popup_520e83a03b4c4f9237a851bf6c3decec)
#         ;
#
#
#
#
#             var poly_line_dc0cf59e0414fc4b4766d438cede66ce = L.polyline(
#                 [[17.50181, 78.30349], [17.50161, 78.30338], [17.50143, 78.30377], [17.50111, 78.30446], [17.5009, 78.30491], [17.50048, 78.3047], [17.50007, 78.30449], [17.49922, 78.30409], [17.49839, 78.30394], [17.49812, 78.3039], [17.49736, 78.30376], [17.49694, 78.30371], [17.49621, 78.30373], [17.49581, 78.30373], [17.49516, 78.30376], [17.49456, 78.30378], [17.49435, 78.3038], [17.4937, 78.30381], [17.49312, 78.30383], [17.49238, 78.30386], [17.49199, 78.30387], [17.4921, 78.3072], [17.49222, 78.30904], [17.49275, 78.31041], [17.49291, 78.31083], [17.49296, 78.31094], [17.4937, 78.31273], [17.49434, 78.31431], [17.49454, 78.31478], [17.49457, 78.31487], [17.4947, 78.31509], [17.49498, 78.3155], [17.49499, 78.31551], [17.49504, 78.31555], [17.49508, 78.3156], [17.4951, 78.31567], [17.49509, 78.31575], [17.49507, 78.3158], [17.49502, 78.31585], [17.49496, 78.31588], [17.49489, 78.31589], [17.49482, 78.31587], [17.49469, 78.31584], [17.49449, 78.31587], [17.49411, 78.31596], [17.4941, 78.3166], [17.49411, 78.31664], [17.49415, 78.31666], [17.49459, 78.31672], [17.49443, 78.31705], [17.4944, 78.31723], [17.4944, 78.31727], [17.49439, 78.31809], [17.49491, 78.31809], [17.4949, 78.31908], [17.49488, 78.32018], [17.49488, 78.32055], [17.49487, 78.32065], [17.49487, 78.32097], [17.49486, 78.32129], [17.49485, 78.32236], [17.49484, 78.32272], [17.49484, 78.32318], [17.49483, 78.32375], [17.49482, 78.3242], [17.49482, 78.32
